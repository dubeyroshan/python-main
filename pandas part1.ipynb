# %% [markdown]
#  ## Pandas

# %%
import pandas as pd
import numpy as np

# %%
list1=['a','b','c','d','e']
list2=[20,30,40,50,60]
array=np.array([1,2,3,4,5])
dict={'w':10,'x':20,'y':30,'z':40,'f':48}

# %%
pd.Series(data=list2)
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# 4    60
# dtype: int64

# %%
pd.Series(data=list2, index=list1)
# Out:
# a    20
# b    30
# c    40
# d    50
# e    60
# dtype: int64

# %%
pd.Series(list1,list2)
# Out:
# 20    a
# 30    b
# 40    c
# 50    d
# 60    e
# dtype: object

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# f    48
# dtype: int64

# %% [markdown]
# ### pandas dataframe and indexng

# %%
sports1=pd.Series([1,2,3,4],index=['cricket','football','tennis','basketball'])

# %%
sports1
# Out:
# cricket       1
# football      2
# tennis        3
# basketball    4
# dtype: int64

# %%
sports1['football']
# Out:
# 2

# %%
sports1['tennis']
# Out:
# 3

# %%
sports2=pd.Series([1,2,3,4],index=['cricket','football','tennis','baseball'])
sports2
# Out:
# cricket     1
# football    2
# tennis      3
# baseball    4
# dtype: int64

# %%
sports1+sports2
# Out:
# baseball      NaN
# basketball    NaN
# cricket       2.0
# football      4.0
# tennis        6.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(5,4),index='A B C D E'.split(),columns='score1 score2 score3 score4'.split())
df1
# Out:
#      score1    score2    score3    score4
# A  0.074045  0.097502  0.013462  0.941352
# B  0.625613  0.804042  0.915509  0.704675
# C  0.861424  0.842634  0.422728  0.264851
# D  0.640440  0.775462  0.850045  0.115664
# E  0.647008  0.445752  0.317540  0.916596

# %%
df1[['score1','score2']]
# Out:
#      score1    score2
# A  0.614684  0.269257
# B  0.093778  0.629408
# C  0.118945  0.950754
# D  0.357353  0.839282
# E  0.693580  0.311748

# %%
df1['score5']=df1['score2']+df1['score2']
df1
# Out:
#      score1    score2    score3    score4    score5
# A  0.614684  0.269257  0.199790  0.811964  0.538515
# B  0.093778  0.629408  0.124021  0.565753  1.258815
# C  0.118945  0.950754  0.927705  0.598523  1.901509
# D  0.357353  0.839282  0.519297  0.792233  1.678564
# E  0.693580  0.311748  0.566958  0.750588  0.623496

# %%
import pandas as pd
import numpy as np

# %%
df2={'ID':['101','102','103','104'],'Name':['john','mrcy','dubey','hello'],'profit':[20,30,40,50]}

# %%
pd=pd.DataFrame(df2)
pd
# Out:
#     ID   Name  profit
# 0  101   john      20
# 1  102   mrcy      30
# 2  103  dubey      40
# 3  104  hello      50

# %%
pd['ID']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# Name: ID, dtype: object

# %%
pd[['ID','Name','profit']]
# Out:
#     ID   Name  profit
# 0  101   john      20
# 1  102   mrcy      30
# 2  103  dubey      40
# 3  104  hello      50

# %%
pd=pd.drop('ID',axis=1)

# %%
pd
# Out:
#     Name  profit
# 0   john      20
# 1   mrcy      30
# 2  dubey      40
# 3  hello      50

# %%
df2={'roll code':[1,2,3,4,5,6],'names':['roshan','rahul','amit','sakshi','suraj','arun'],'marks':[100,50,40,56,88,68]}

# %%
df2=pd.DataFrame(df2)
df2
# Out:
#    roll code   names  marks
# 0          1  roshan    100
# 1          2   rahul     50
# 2          3    amit     40
# 3          4  sakshi     56
# 4          5   suraj     88
# 5          6    arun     68

# %% [markdown]
# ### how to import dataset using Pandas

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dubeyroshan/Datasets/main/CardioGoodFitness-1.csv")

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.shape
# Out:
# (180, 9)

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.head(2)
# Out:
#   Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18   Male         14        Single      3        4   29562    112
# 1   TM195   19   Male         15        Single      2        3   31836     75

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.sample()
# Out:
#    Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 90   TM498   23   Male         16     Partnered      4        3   45480    127

# %%
df.sample(10)    ##random selecting
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 44    TM195   28  Female         14     Partnered      2        3   46617
# 6     TM195   21  Female         14     Partnered      3        3   35247
# 32    TM195   25  Female         16     Partnered      2        2   40932
# 148   TM798   24  Female         16        Single      5        5   52291
# 117   TM498   31  Female         18        Single      2        1   65220
# 7     TM195   21    Male         13        Single      3        3   32973
# 45    TM195   28  Female         16     Partnered      2        3   52302
# 92    TM498   23  Female         14        Single      3        2   40932
# 16    TM195   23  Female         14        Single      2        3   34110
# 13    TM195   22  Female         14        Single      3        3   35247
#
#      Miles
# 44      56
# 6       75
# 32      47
# 148    200
# 117     21
# 7       85
# 45      66
# 92      53
# 16     103
# 13      75

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dubeyroshan/Datasets/main/HousePrices.csv")

# %%
df
# Out:
#         Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0        1          60         RL         65.0     8450      Pave   NaN
# 1        2          20         RL         80.0     9600      Pave   NaN
# 2        3          60         RL         68.0    11250      Pave   NaN
# 3        4          70         RL         60.0     9550      Pave   NaN
# 4        5          60         RL         84.0    14260      Pave   NaN
# ...    ...         ...        ...          ...      ...       ...   ...
# 1455  1456          60         RL         62.0     7917      Pave   NaN
# 1456  1457          20         RL         85.0    13175      Pave   NaN
# 1457  1458          70         RL         66.0     9042      Pave   NaN
# 1458  1459          20         RL         68.0     9717      Pave   NaN
# 1459  1460          20         RL         75.0     9937      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  Property_Sale_Price
# ...

# %%
df.head(25)
# Out:
#     Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0    1          60         RL         65.0     8450      Pave   NaN
# 1    2          20         RL         80.0     9600      Pave   NaN
# 2    3          60         RL         68.0    11250      Pave   NaN
# 3    4          70         RL         60.0     9550      Pave   NaN
# 4    5          60         RL         84.0    14260      Pave   NaN
# 5    6          50         RL         85.0    14115      Pave   NaN
# 6    7          20         RL         75.0    10084      Pave   NaN
# 7    8          60         RL          NaN    10382      Pave   NaN
# 8    9          50         RM         51.0     6120      Pave   NaN
# 9   10         190         RL         50.0     7420      Pave   NaN
# 10  11          20         RL         70.0    11200      Pave   NaN
# 11  12          60         RL         85.0    11924      Pave   NaN
# 12  13          20         RL          NaN    12968      Pave   NaN
# ...

# %%
df.tail()
# Out:
#         Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 1455  1456          60         RL         62.0     7917      Pave   NaN
# 1456  1457          20         RL         85.0    13175      Pave   NaN
# 1457  1458          70         RL         66.0     9042      Pave   NaN
# 1458  1459          20         RL         68.0     9717      Pave   NaN
# 1459  1460          20         RL         75.0     9937      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# 1455            Reg         Lvl    AllPub  ...        0    NaN    NaN
# 1456            Reg         Lvl    AllPub  ...        0    NaN  MnPrv
# 1457            Reg         Lvl    AllPub  ...        0    NaN  GdPrv
# 1458            Reg         Lvl    AllPub  ...        0    NaN    NaN
# 1459            Reg         Lvl    AllPub  ...        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# ...

# %%
df.tail(25)
# Out:
#         Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 1435  1436          20         RL         80.0     8400      Pave   NaN
# 1436  1437          20         RL         60.0     9000      Pave   NaN
# 1437  1438          20         RL         96.0    12444      Pave   NaN
# 1438  1439          20         RM         90.0     7407      Pave   NaN
# 1439  1440          60         RL         80.0    11584      Pave   NaN
# 1440  1441          70         RL         79.0    11526      Pave   NaN
# 1441  1442         120         RM          NaN     4426      Pave   NaN
# 1442  1443          60         FV         85.0    11003      Pave   NaN
# 1443  1444          30         RL          NaN     8854      Pave   NaN
# 1444  1445          20         RL         63.0     8500      Pave   NaN
# 1445  1446          85         RL         70.0     8400      Pave   NaN
# 1446  1447          20         RL          NaN    26142      Pave   NaN
# ...

# %%
df.sample()
# Out:
#       Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 435  436          60         RL         43.0    10667      Pave   NaN
#
#     Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence  \
# 435            IR2         Lvl    AllPub  ...        0    NaN   NaN
#
#     MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# 435         NaN       0      4   2009     ConLw         Normal
#
#      Property_Sale_Price
# 435               212000
#
# [1 rows x 81 columns]

# %%
df.sample()
# Out:
#       Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 450  451          30         RM         70.0     5684      Pave   NaN
#
#     Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence  \
# 450            Reg         Lvl    AllPub  ...        0    NaN   NaN
#
#     MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# 450         NaN       0      6   2006        WD         Normal
#
#      Property_Sale_Price
# 450               110000
#
# [1 rows x 81 columns]

# %%
df.sample(5)
# Out:
#       Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 82    83          20         RL         78.0    10206      Pave   NaN
# 727  728          20         RL         64.0     7314      Pave   NaN
# 385  386         120         RL         43.0     3182      Pave   NaN
# 815  816          20         RL         48.0    12137      Pave   NaN
# 188  189          90         RL         64.0     7018      Pave   NaN
#
#     Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence  \
# 82             Reg         Lvl    AllPub  ...        0    NaN   NaN
# 727            Reg         Lvl    AllPub  ...        0    NaN   NaN
# 385            Reg         Lvl    AllPub  ...        0    NaN   NaN
# 815            IR2         Lvl    AllPub  ...        0    NaN   NaN
# 188            Reg         Bnk    AllPub  ...        0    NaN   NaN
#
#     MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# 82          NaN       0     10   2008        WD         Normal
# ...

# %%
df.dtypes
# Out:
# Id                       int64
# Dwell_Type               int64
# Zone_Class              object
# LotFrontage            float64
# LotArea                  int64
#                         ...
# MoSold                   int64
# YrSold                   int64
# SaleType                object
# SaleCondition           object
# Property_Sale_Price      int64
# Length: 81, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1460 non-null   int64
#  1   Dwell_Type           1460 non-null   int64
#  2   Zone_Class           1460 non-null   object
#  3   LotFrontage          1201 non-null   float64
#  4   LotArea              1460 non-null   int64
#  5   Road_Type            1460 non-null   object
#  6   Alley                91 non-null     object
#  7   Property_Shape       1460 non-null   object
#  8   LandContour          1460 non-null   object
#  9   Utilities            1460 non-null   object
#  10  LotConfig            1460 non-null   object
#  11  LandSlope            1460 non-null   object
#  12  Neighborhood         1460 non-null   object
#  13  Condition1           1460 non-null   object
#  14  Condition2           1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                       0
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            259
# LotArea                  0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 81, dtype: int64

# %%
df.describe()
# Out:
#                 Id   Dwell_Type  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.describe(include='all')
# Out:
#                  Id   Dwell_Type Zone_Class  LotFrontage        LotArea  \
# count   1460.000000  1460.000000       1460  1201.000000    1460.000000
# unique          NaN          NaN          5          NaN            NaN
# top             NaN          NaN         RL          NaN            NaN
# freq            NaN          NaN       1151          NaN            NaN
# mean     730.500000    56.897260        NaN    70.049958   10516.828082
# std      421.610009    42.300571        NaN    24.284752    9981.264932
# min        1.000000    20.000000        NaN    21.000000    1300.000000
# 25%      365.750000    20.000000        NaN    59.000000    7553.500000
# 50%      730.500000    50.000000        NaN    69.000000    9478.500000
# 75%     1095.250000    70.000000        NaN    80.000000   11601.500000
# max     1460.000000   190.000000        NaN   313.000000  215245.000000
#
#        Road_Type Alley Property_Shape LandContour Utilities  ...     PoolArea  \
# ...
